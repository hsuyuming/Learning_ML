# %%
import tensorflow as tf

from tfx import v1 as tfx
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/.local/share/virtualenvs/feature_selection-yCDCSZCi/lib/python3.9/site-packages/pkg_resources/__init__.py:3037, in DistInfoDistribution._dep_map(self)
#    <a href='file:///Users/abehsu/.local/share/virtualenvs/feature_selection-yCDCSZCi/lib/python3.9/site-packages/pkg_resources/__init__.py?line=3035'>3036</a> try:
# -> <a href='file:///Users/abehsu/.local/share/virtualenvs/feature_selection-yCDCSZCi/lib/python3.9/site-packages/pkg_resources/__init__.py?line=3036'>3037</a>     return self.__dep_map
#    <a href='file:///Users/abehsu/.local/share/virtualenvs/feature_selection-yCDCSZCi/lib/python3.9/site-packages/pkg_resources/__init__.py?line=3037'>3038</a> except AttributeError:
#
# ...
